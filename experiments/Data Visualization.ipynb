# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from PIL import Image 

# %matplotlib inline

# %%
# configure data directories
data_dir = r'C:\Users\hello\Projects\Multimodal-VQ-VAE\data'
train_rgb_dir = os.path.join(data_dir, 'images_rgb_train')
train_thermal_dir = os.path.join(data_dir, 'images_thermal_train')

# %% [markdown]
# # Visualize RGB images

# %%
rgb_img_path = os.path.join(train_rgb_dir, os.listdir(train_rgb_dir)[0])
rgb_img = Image.open(rgb_img_path)
print(f'Visualizing: ' + rgb_img_path)
display(rgb_img)
# Out:
# Visualizing: C:\Users\hello\Projects\Multimodal-VQ-VAE\data\images_rgb_train\FLIR_00002_RGB.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x512>

# %% [markdown]
# ## Visualize Thermal images

# %%
import cv2

rgb_img = cv2.imread(rgb_img_path)
print(rgb_img.shape)
# Out:
# (512, 640, 3)

# %%
thermal_img_path = os.path.join(train_thermal_dir, os.listdir(train_thermal_dir)[0])
thermal_img = Image.open(thermal_img_path)
print(f'Visualizing: ' + thermal_img_path)
display(thermal_img)
# Out:
# Visualizing: C:\Users\hello\Projects\Multimodal-VQ-VAE\data\images_thermal_train\FLIR_00002_PreviewData.jpeg
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=640x512>
